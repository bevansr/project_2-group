# %%
import pandas as pd
import requests
import json
from pprint import pprint
# url = 'https://data.cityofchicago.org/resource/tdab-kixi.json'
json_file = "Resources/landmarks.json"

customer_location_df = pd.read_json(json_file)

# %%
pd.read_json(json_file)
# pprint(requests.get(url).json())
# Out:
# [{':@computed_region_43wa_7qmu': '40',
#   ':@computed_region_6mkv_f3dw': '22535',
#   ':@computed_region_awaf_s7ux': '24',
#   ':@computed_region_bdys_3d7i': '240',
#   ':@computed_region_rpca_8um6': '1',
#   ':@computed_region_vrxf_vc4k': '23',
#   'address': '2543 - 2545 W Diversey Av',
#   'id': 'L-265',
#   'landmark_designation_date': '2008-07-30T07:00:00.000Z',
#   'landmark_name': 'Vassar Swiss Underwear Company Building',
#   'latitude': '41.93162660840',
#   'location': {'latitude': '41.9316266084', 'longitude': '-87.6921000957'},
#   'longitude': '-87.69210009570'},
#  {':@computed_region_43wa_7qmu': '10',
#   ':@computed_region_6mkv_f3dw': '4301',
#   ':@computed_region_awaf_s7ux': '1',
#   ':@computed_region_bdys_3d7i': '220',
#   ':@computed_region_rpca_8um6': '36',
#   ':@computed_region_vrxf_vc4k': '2',
#   'address': '4122 S Ellis Av',
#   'architect': 'Adler & Sullivan',
#   'date_built': '1886',
#   'id': 'L- 89',
# ...
