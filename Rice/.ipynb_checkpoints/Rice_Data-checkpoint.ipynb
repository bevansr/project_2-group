# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
file_landmarks = "Resources/Landmarks_Complete.csv"
file_murals = "Resources/Mural_Registry.csv"


landmarks_df = pd.read_csv(file_landmarks)
murals_df = pd.read_csv(file_murals)

# %%
landmarks_df
# Out:
#                                          LANDMARK NAME     ID  \
# 0              Vassar Swiss Underwear Company Building  L-265
# 1                                 Mathilde Eliel House  L- 89
# 2                                   Manhattan Building  L-139
# 3    Machinery Hall at Illinois Institute of Techno...  L- 12
# 4                               Melissa Ann Elam House  L- 88
# ..                                                 ...    ...
# 309   (Former) Schlitz BreweryTied-House@1944 N.Oakley  L-310
# 310                                         Getty Tomb  L-103
# 311                       Engine Company 129, Truck 50  L-236
# 312                               James Charnley House  L- 65
# 313                       Beeson House and Coach House  L-224
#
#                                  ADDRESS DATE BUILT  \
# 0              2543 - 2545 W Diversey Av        NaN
# 1                        4122 S Ellis Av       1886
# 2                      431 S Dearborn St       1891
# ...

# %%
landmarks_df.columns= landmarks_df.columns.str.lower()
landmarks_df
# Out:
#                                          landmark name     id  \
# 0              Vassar Swiss Underwear Company Building  L-265
# 1                                 Mathilde Eliel House  L- 89
# 2                                   Manhattan Building  L-139
# 3    Machinery Hall at Illinois Institute of Techno...  L- 12
# 4                               Melissa Ann Elam House  L- 88
# ..                                                 ...    ...
# 309   (Former) Schlitz BreweryTied-House@1944 N.Oakley  L-310
# 310                                         Getty Tomb  L-103
# 311                       Engine Company 129, Truck 50  L-236
# 312                               James Charnley House  L- 65
# 313                       Beeson House and Coach House  L-224
#
#                                  address date built  \
# 0              2543 - 2545 W Diversey Av        NaN
# 1                        4122 S Ellis Av       1886
# 2                      431 S Dearborn St       1891
# ...

# %%
landmarks_df = landmarks_df.rename(columns={'landmark name': 'name', 'architect': 'artist', 'date built': 'year installed'})
landmarks_df
# Out:
#                                                   name     id  \
# 0              Vassar Swiss Underwear Company Building  L-265
# 1                                 Mathilde Eliel House  L- 89
# 2                                   Manhattan Building  L-139
# 3    Machinery Hall at Illinois Institute of Techno...  L- 12
# 4                               Melissa Ann Elam House  L- 88
# ..                                                 ...    ...
# 309   (Former) Schlitz BreweryTied-House@1944 N.Oakley  L-310
# 310                                         Getty Tomb  L-103
# 311                       Engine Company 129, Truck 50  L-236
# 312                               James Charnley House  L- 65
# 313                       Beeson House and Coach House  L-224
#
#                                  address year installed  \
# 0              2543 - 2545 W Diversey Av            NaN
# 1                        4122 S Ellis Av           1886
# ...

# %%
landmarks_df.columns
# Out:
# Index(['name', 'id', 'address', 'year installed', 'artist',
#        'landmark designation date', 'latitude', 'longitude', 'location',
#        'zip code', 'type'],
#       dtype='object')

# %%
landmarks_df = landmarks_df[['name', 'address', 'year installed', 'artist',
       'landmark designation date', 'latitude', 'longitude','zip code', 'type']]
landmarks_df
# Out:
#                                                   name  \
# 0              Vassar Swiss Underwear Company Building
# 1                                 Mathilde Eliel House
# 2                                   Manhattan Building
# 3    Machinery Hall at Illinois Institute of Techno...
# 4                               Melissa Ann Elam House
# ..                                                 ...
# 309   (Former) Schlitz BreweryTied-House@1944 N.Oakley
# 310                                         Getty Tomb
# 311                       Engine Company 129, Truck 50
# 312                               James Charnley House
# 313                       Beeson House and Coach House
#
#                                  address year installed  \
# 0              2543 - 2545 W Diversey Av            NaN
# 1                        4122 S Ellis Av           1886
# 2                      431 S Dearborn St           1891
# 3             100 W 33rd St, Chicago, IL           1901
# ...

# %%
#landmarks_df = landmarks_df[landmarks_df['latitude'].dropna()]
#landmarks_df = landmarks_df[landmarks_df['longitude'].dropna()]
landmarks_df = landmarks_df[landmarks_df['landmark designation date'].notna()]


landmarks_df.dropna(subset=['longitude', 'latitude', 'landmark designation date'])
#landmarks_df['year installed'].fillna(0, inplace=True)
landmarks_df['install date'] = landmarks_df['year installed'].str[:4]
del landmarks_df['year installed']
landmarks_df
# Out:
# C:\Users\lauri\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                   name  \
# 0              Vassar Swiss Underwear Company Building
# 1                                 Mathilde Eliel House
# 2                                   Manhattan Building
# 3    Machinery Hall at Illinois Institute of Techno...
# 4                               Melissa Ann Elam House
# ..                                                 ...
# 309   (Former) Schlitz BreweryTied-House@1944 N.Oakley
# 310                                         Getty Tomb
# 311                       Engine Company 129, Truck 50
# 312                               James Charnley House
# ...

# %%
landmarks_df['designation date'] = pd.DatetimeIndex(landmarks_df['landmark designation date']).year
del landmarks_df['landmark designation date']
landmarks_df
# Out:
# C:\Users\lauri\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                   name  \
# 0              Vassar Swiss Underwear Company Building
# 1                                 Mathilde Eliel House
# 2                                   Manhattan Building
# 3    Machinery Hall at Illinois Institute of Techno...
# 4                               Melissa Ann Elam House
# ..                                                 ...
# 309   (Former) Schlitz BreweryTied-House@1944 N.Oakley
# 310                                         Getty Tomb
# 311                       Engine Company 129, Truck 50
# ...

# %%
landmarks_df['designation date'] = landmarks_df['designation date'].astype(int)
# Out:
# C:\Users\lauri\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
landmarks_df.columns
# Out:
# Index(['name', 'address', 'artist', 'latitude', 'longitude', 'zip code',
#        'type', 'install date', 'designation date'],
#       dtype='object')

# %%
landmarks_df[['name', 'address', 'artist', 'install date', 'latitude',
       'longitude', 'zip code', 'type', 'designation date']]
# Out:
#                                                   name  \
# 0              Vassar Swiss Underwear Company Building
# 1                                 Mathilde Eliel House
# 2                                   Manhattan Building
# 3    Machinery Hall at Illinois Institute of Techno...
# 4                               Melissa Ann Elam House
# ..                                                 ...
# 309   (Former) Schlitz BreweryTied-House@1944 N.Oakley
# 310                                         Getty Tomb
# 311                       Engine Company 129, Truck 50
# 312                               James Charnley House
# 313                       Beeson House and Coach House
#
#                                  address  \
# 0              2543 - 2545 W Diversey Av
# 1                        4122 S Ellis Av
# 2                      431 S Dearborn St
# 3             100 W 33rd St, Chicago, IL
# 4     4726 S Dr Martin Luther King Jr Dr
# ..                                   ...
# ...

# %%
murals_df
# Out:
#      Mural Registration ID                      Artist Credit  \
# 0                    19006                  John Pitman Weber
# 1                    19043        Rahmaan Statik, Max Sansing
# 2                    19064            Damon Reed & Moses Ball
# 3                    19154                         Shawnimals
# 4                    19161                        Cara Feeney
# ..                     ...                                ...
# 351                  19310                         Justus Roe
# 352                  19216                    Uneek and Flash
# 353                  19223   Todd Osborne and Tracy VanDuinen
# 354                  19233                    Matthew Hoffman
# 355                  19101  Mirtes Zwierzynski, Ruben Aguirre
#
#                              Artwork Title                             Media  \
# 0    TILT (Together Protect the Community)                               NaN
# ...

# %%
murals_df = murals_df.rename(columns={'Mural Registration ID': 'ID','Artist Credit': 'Artist', 'Zip': 'Zip Code', 'Street Address': 'Address', 'Artwork Title': 'Name'})
murals_df
# Out:
#         ID                             Artist  \
# 0    19006                  John Pitman Weber
# 1    19043        Rahmaan Statik, Max Sansing
# 2    19064            Damon Reed & Moses Ball
# 3    19154                         Shawnimals
# 4    19161                        Cara Feeney
# ..     ...                                ...
# 351  19310                         Justus Roe
# 352  19216                    Uneek and Flash
# 353  19223   Todd Osborne and Tracy VanDuinen
# 354  19233                    Matthew Hoffman
# 355  19101  Mirtes Zwierzynski, Ruben Aguirre
#
#                                       Name                             Media  \
# 0    TILT (Together Protect the Community)                               NaN
# 1                                    Sepia                             Paint
# 2                            Change Makers                               NaN
# 3                                      NaN                             Paint
# ...

# %%
murals_df.columns
# Out:
# Index(['ID', 'Artist', 'Name', 'Media', 'Year Installed', 'Year Restored',
#        'Location Description', 'Address', 'Zip Code', 'Ward',
#        'Community Area Number', 'Affiliated (or Commissioning) Organization',
#        'Description of Artwork', 'Latitude', 'Longitude', 'Location', 'Type'],
#       dtype='object')

# %%
murals_df = murals_df[['Artist', 'Name',
       'Year Installed', 'Address', 'Zip Code', 'Description of Artwork',
       'Latitude', 'Longitude', 'Type']]
murals_df
# Out:
#                                 Artist                                   Name  \
# 0                    John Pitman Weber  TILT (Together Protect the Community)
# 1          Rahmaan Statik, Max Sansing                                  Sepia
# 2              Damon Reed & Moses Ball                          Change Makers
# 3                           Shawnimals                                    NaN
# 4                          Cara Feeney                        Community Mural
# ..                                 ...                                    ...
# 351                         Justus Roe                         16th & Ashland
# 352                    Uneek and Flash                         Block by Block
# 353   Todd Osborne and Tracy VanDuinen    Sauganash Mural Project, North Wall
# 354                    Matthew Hoffman                      You Are Beautiful
# 355  Mirtes Zwierzynski, Ruben Aguirre                   Parkside of Old Town
#
# ...

# %%
#murals_df = murals_df[murals_df['Latitude'].notna()]
#murals_df = murals_df[murals_df['Longitude'].notna()]

murals_df.dropna(subset=['Longitude', 'Latitude'])
murals_df
# Out:
#                                 Artist                                   Name  \
# 0                    John Pitman Weber  TILT (Together Protect the Community)
# 1          Rahmaan Statik, Max Sansing                                  Sepia
# 2              Damon Reed & Moses Ball                          Change Makers
# 3                           Shawnimals                                    NaN
# 4                          Cara Feeney                        Community Mural
# ..                                 ...                                    ...
# 351                         Justus Roe                         16th & Ashland
# 352                    Uneek and Flash                         Block by Block
# 353   Todd Osborne and Tracy VanDuinen    Sauganash Mural Project, North Wall
# 354                    Matthew Hoffman                      You Are Beautiful
# 355  Mirtes Zwierzynski, Ruben Aguirre                   Parkside of Old Town
#
# ...

# %%
murals_df['Year Installed'] = murals_df['Year Installed'].astype(str)
murals_df['Install Date'] = murals_df['Year Installed'].str[:4]
del murals_df['Year Installed']
murals_df
# Out:
# C:\Users\lauri\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\lauri\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 Artist                                   Name  \
# 0                    John Pitman Weber  TILT (Together Protect the Community)
# ...

# %%
murals_df.columns= murals_df.columns.str.lower()
murals_df
# Out:
#                                 artist                                   name  \
# 0                    John Pitman Weber  TILT (Together Protect the Community)
# 1          Rahmaan Statik, Max Sansing                                  Sepia
# 2              Damon Reed & Moses Ball                          Change Makers
# 3                           Shawnimals                                    NaN
# 4                          Cara Feeney                        Community Mural
# ..                                 ...                                    ...
# 351                         Justus Roe                         16th & Ashland
# 352                    Uneek and Flash                         Block by Block
# 353   Todd Osborne and Tracy VanDuinen    Sauganash Mural Project, North Wall
# 354                    Matthew Hoffman                      You Are Beautiful
# 355  Mirtes Zwierzynski, Ruben Aguirre                   Parkside of Old Town
#
# ...

# %%
murals_df.columns
# Out:
# Index(['artist', 'name', 'address', 'zip code', 'description of artwork',
#        'latitude', 'longitude', 'type', 'install date'],
#       dtype='object')

# %%
murals_df = murals_df[['artist', 'name', 'address', 'install date', 'zip code', 'description of artwork',
       'latitude', 'longitude', 'type']]
murals_df
# Out:
#                                 artist                                   name  \
# 0                    John Pitman Weber  TILT (Together Protect the Community)
# 1          Rahmaan Statik, Max Sansing                                  Sepia
# 2              Damon Reed & Moses Ball                          Change Makers
# 3                           Shawnimals                                    NaN
# 4                          Cara Feeney                        Community Mural
# ..                                 ...                                    ...
# 351                         Justus Roe                         16th & Ashland
# 352                    Uneek and Flash                         Block by Block
# 353   Todd Osborne and Tracy VanDuinen    Sauganash Mural Project, North Wall
# 354                    Matthew Hoffman                      You Are Beautiful
# 355  Mirtes Zwierzynski, Ruben Aguirre                   Parkside of Old Town
#
# ...

# %%
landmarks_df.dtypes
# Out:
# name                 object
# address              object
# artist               object
# latitude            float64
# longitude           float64
# zip code             object
# type                 object
# install date         object
# designation date      int32
# dtype: object

# %%
murals_df.dtypes
# Out:
# artist                     object
# name                       object
# address                    object
# install date               object
# zip code                  float64
# description of artwork     object
# latitude                  float64
# longitude                  object
# type                       object
# dtype: object

# %%
murals_df = murals_df[murals_df['zip code'].notna()]
murals_df['zip code'] = murals_df['zip code'].astype(int)
murals_df
# Out:
# C:\Users\lauri\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 artist                                   name  \
# 0                    John Pitman Weber  TILT (Together Protect the Community)
# 1          Rahmaan Statik, Max Sansing                                  Sepia
# 2              Damon Reed & Moses Ball                          Change Makers
# 3                           Shawnimals                                    NaN
# 4                          Cara Feeney                        Community Mural
# ..                                 ...                                    ...
# ...

# %%
murals_df['longitude'] = pd.to_numeric(murals_df['longitude'], errors='coerce')
murals_df['zip code'] = murals_df['zip code'].astype(str)
# Out:
# C:\Users\lauri\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\lauri\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
murals_df.dtypes
# Out:
# artist                     object
# name                       object
# address                    object
# install date               object
# zip code                   object
# description of artwork     object
# latitude                  float64
# longitude                 float64
# type                       object
# dtype: object

# %%
landmarks_df.dtypes
# Out:
# name                 object
# address              object
# artist               object
# latitude            float64
# longitude           float64
# zip code             object
# type                 object
# install date         object
# designation date      int32
# dtype: object

# %%
chicago_df = pd.merge(landmarks_df, murals_df, on=['name', 'artist', 'install date', 'address', 'latitude', 'longitude', 'type', 'zip code'], how='outer')
chicago_df
# Out:
#                                                   name  \
# 0              Vassar Swiss Underwear Company Building
# 1                                 Mathilde Eliel House
# 2                                   Manhattan Building
# 3    Machinery Hall at Illinois Institute of Techno...
# 4                               Melissa Ann Elam House
# ..                                                 ...
# 651                                     16th & Ashland
# 652                                     Block by Block
# 653                Sauganash Mural Project, North Wall
# 654                                  You Are Beautiful
# 655                               Parkside of Old Town
#
#                                 address                             artist  \
# 0             2543 - 2545 W Diversey Av                                NaN
# 1                       4122 S Ellis Av                   Adler & Sullivan
# 2                     431 S Dearborn St             William LeBaron Jenney
# ...

# %%
chicago_df.columns = chicago_df.columns.str.replace(' ', '_')
chicago_df
# Out:
#                                                   name  \
# 0              Vassar Swiss Underwear Company Building
# 1                                 Mathilde Eliel House
# 2                                   Manhattan Building
# 3    Machinery Hall at Illinois Institute of Techno...
# 4                               Melissa Ann Elam House
# ..                                                 ...
# 651                                     16th & Ashland
# 652                                     Block by Block
# 653                Sauganash Mural Project, North Wall
# 654                                  You Are Beautiful
# 655                               Parkside of Old Town
#
#                                 address                             artist  \
# 0             2543 - 2545 W Diversey Av                                NaN
# 1                       4122 S Ellis Av                   Adler & Sullivan
# 2                     431 S Dearborn St             William LeBaron Jenney
# ...

# %%
chicago_df['name'] = chicago_df['name'].replace(np.nan, 'Unknown', regex=True)
chicago_df['address'] = chicago_df['address'].replace(np.nan, 'Unknown', regex=True)
chicago_df['artist'] = chicago_df['artist'].replace(np.nan, 'Unknown', regex=True)
chicago_df['designation_date'] = chicago_df['designation_date'].replace(np.nan, 'Unknown', regex=True)
chicago_df['zip_code'] = chicago_df['zip_code'].replace(np.nan, 'Unknown', regex=True)
chicago_df['description_of_artwork'] = chicago_df['description_of_artwork'].replace(np.nan, 'None', regex=True)
murals_df.dropna(subset=['longitude', 'latitude'])
chicago_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'designation_date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-75c2da8c6d27> in <module>
# ...

# %%
# THIS IS MY TROUBLESHOOTING CELL
#chicago_df = chicago_df[chicago_df['latitude'].notna()]
#chicago_df = chicago_df[chicago_df['longitude'].notna()]
#TS = chicago_df.loc[chicago_df['name'] == 'We Grow Here Too', :]
#TS

# %%
chicago_df = chicago_df.replace(',', ';', regex=True)
chicago_df = chicago_df.replace('�', ';', regex=True)
chicago_df = chicago_df.replace('\n', ' ', regex=True)
chicago_df
# Out:
#                                                   name  \
# 0              Vassar Swiss Underwear Company Building
# 1                                 Mathilde Eliel House
# 2                                   Manhattan Building
# 3    Machinery Hall at Illinois Institute of Techno...
# 4                               Melissa Ann Elam House
# ..                                                 ...
# 664                                     16th & Ashland
# 665                                     Block by Block
# 666                Sauganash Mural Project; North Wall
# 667                                  You Are Beautiful
# 668                               Parkside of Old Town
#
#                                 address                             artist  \
# 0             2543 - 2545 W Diversey Av                            Unknown
# 1                       4122 S Ellis Av                   Adler & Sullivan
# 2                     431 S Dearborn St             William LeBaron Jenney
# ...

# %%
chicago_df.dtypes
# Out:
# name                          object
# address                       object
# artist                        object
# landmark_designation_date     object
# latitude                     float64
# longitude                    float64
# zip_code                      object
# type                          object
# install_date                  object
# description_of_artwork        object
# dtype: object

# %%
chicago_df['longitude'] = chicago_df['longitude'].astype(float)

# %%
chicago_df.dtypes
# Out:
# name                          object
# address                       object
# artist                        object
# landmark_designation_date     object
# latitude                     float64
# longitude                    float64
# zip_code                      object
# type                          object
# install_date                  object
# description_of_artwork        object
# dtype: object

# %%
chicago_df.columns
# Out:
# Index(['name', 'address', 'artist', 'landmark_designation_date', 'latitude',
#        'longitude', 'zip_code', 'type', 'install_date',
#        'description_of_artwork'],
#       dtype='object')

# %%
engine = create_engine(f"postgresql://postgres:6472@localhost:5432/Landmarks")

engine.table_names()
# Out:
# ['chicago_df']

# %%
chicago_df.to_sql(name='chicago_df', con=engine, if_exists='append', index=False)
