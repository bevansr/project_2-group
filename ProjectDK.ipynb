# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sqlalchemy
import psycopg2

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(f"postgresql://postgres:B7b3t8t8!@localhost:5432/chicago")
connection = engine.connect()

# %%
lmark_df = pd.read_sql("select * from landmarks", connection)
lmark_df.fillna("NaN")
# Out:
#                                                   name  \
# 0              Vassar Swiss Underwear Company Building
# 1                                 Mathilde Eliel House
# 2                                   Manhattan Building
# 3    Machinery Hall at Illinois Institute of Techno...
# 4                               Melissa Ann Elam House
# ..                                                 ...
# 651                                     16th & Ashland
# 652                                     Block by Block
# 653                Sauganash Mural Project; North Wall
# 654                                  You Are Beautiful
# 655                               Parkside of Old Town
#
#                                 address install_date designation_date  \
# 0             2543 - 2545 W Diversey Av          NaN             2008
# 1                       4122 S Ellis Av         1886             1991
# 2                     431 S Dearborn St         1891             1978
# ...
